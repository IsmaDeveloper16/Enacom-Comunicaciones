# %% [markdown]
# Aqui estare realizando mi **EDA(Analisys exploratorio de datos)**

# %% [markdown]
# importamos las librerias que estaremos usando

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Comenzare por los datos generales.

# %% [markdown]
# importare a un dataframe el csv banda_ancha_general

# %%
banda_ancha_general = pd.read_csv('nuevos_datos/banda_ancha_general.csv')

# %%
banda_ancha_general
# Out:
#      Año  Trimestre  Banda ancha fija  Dial up  Total        Periodo
# 0   2022          4                11       12     23   Oct-Dic 2022
# 1   2022          3                11       12     23  Jul-Sept 2022
# 2   2022          2                11       12     23   Abr-Jun 2022
# 3   2022          1                11       13     24   Ene-Mar 2022
# 4   2021          4                10       13     23   Oct-Dic 2021
# 5   2021          3                10       10     20  Jul-Sept 2021
# 6   2021          2                10       10     20   Abr-Jun 2021
# 7   2021          1                10       10     20   Ene-Mar 2021
# 8   2020          4                10       10     20   Oct-Dic 2020
# 9   2020          3                 9       10     19  Jul-Sept 2020
# 10  2020          2                 9       10     19   Abr-Jun 2020
# 11  2020          1                 9       10     19   Ene-Mar 2020
# 12  2019          4                 9       10     19   Oct-Dic 2019
# ...

# %% [markdown]
# Al tener pocos datos, se puede notar a simple vista que no contiene valores fatantes. ahora hare un boxplot de las columnas 'Banda ancha fija', 'Dial up' y 'Total' para buscar valores atipicos.

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1,2,1)
sns.boxplot(data=banda_ancha_general['Banda ancha fija'])
plt.title('Banda ancha fija')
plt.subplot(1,2,2)
sns.boxplot(data=banda_ancha_general['Dial up'])
plt.title('Dial up')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Como vemos en el grafico de arriba, parece indicar que no contiene valores atipicos.

# %% [markdown]
# Continuemos con velocidad general.

# %%
velocidad_general = pd.read_csv('nuevos_datos/velocidad_general.csv')

# %%
velocidad_general.head(1)
# Out:
#     Año  Trimestre  Más de 30 Mbps   OTROS     Total       Periodo  \
# 0  2022          4         7410902  394282  11208114  Oct-Dic 2022
#
#    hasta 1 Mbps  1 Mbps - 10 Mbps  10 Mbps - 30 Mbps
# 0        117649           2184693            1100588

# %% [markdown]
# Al contener pocos datos se ve a simple vista que no contiene valores nulos, ahora hare un diagrama de caja para buscar valores atipicos.

# %% [markdown]
# comenzaremos con 1 mbps hasta 30 mbps

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1,3,1)
sns.boxplot(data=velocidad_general['hasta 1 Mbps'])
plt.title('hasta 1 mbps')

plt.subplot(1,3,2)
sns.boxplot(data=velocidad_general['1 Mbps - 10 Mbps'])
plt.title('1mbps - 10mbps')

plt.subplot(1,3,3)
sns.boxplot(data=velocidad_general['10 Mbps - 30 Mbps'])
plt.title('10mbps - 30mbps')
plt.show()

# %% [markdown]
# Como indican los graficos no contienen valores atipicos.

# %% [markdown]
# Ahora seguiremos con las 3 columnas faltantes.

# %%
plt.figure(figsize=(15, 4))
plt.subplot(1,3,1)
sns.boxplot(data=velocidad_general['Más de 30 Mbps'])
plt.title('mas de 30 mbps')

plt.subplot(1,3,2)
sns.boxplot(data=velocidad_general['OTROS'])
plt.title('OTROS')

plt.subplot(1,3,3)
sns.boxplot(data=velocidad_general['Total'])
plt.title('Total')
plt.show()

# %% [markdown]
# Como vemos en los graficos no contienen valores atipicos

# %%
tecnologia_general = pd.read_csv('nuevos_datos/tecnologia_general.csv')

# %%
tecnologia_general.head(1)
# Out:
#     Año  Trimestre  ADSL  Cablemodem  Fibra óptica  Wireless  Otros  \
# 0  2022          4     1           6             3       573    222
#
#         Periodo  Total_tecnologia
# 0  Oct-Dic 2022               805

# %% [markdown]
# Al ser pocos datos, a simple vista notamos que no contiene valores faltantes.

# %%
plt.figure(figsize=(15, 4))
plt.subplot(1,3,1)
sns.boxplot(data=tecnologia_general['ADSL'])
plt.title('ADSL')

plt.subplot(1,3,2)
sns.boxplot(data=tecnologia_general['Cablemodem'])
plt.title('Cablemodem')

plt.subplot(1,3,3)
sns.boxplot(data=tecnologia_general['Fibra óptica'])
plt.title('Fibra optica')

plt.show()

# %% [markdown]
# Como vemos en los graficos en la parte de fibra optica vemos que contiene algunos valores considerados atipicos, pero investigando los datos y las fuentes vemos que parece que estan mal cargados los datos porque cuando los valores son mayores a 1000 se quedan en una unidad o digito, por lo tanto no eliminare valores que parecen atipicos pero no parecen serlos.

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
sns.boxplot(data=tecnologia_general['Wireless'])
plt.title('Wireless')

plt.subplot(1,3,2)
sns.boxplot(data=tecnologia_general['Otros'])
plt.title('Otros')

plt.subplot(1,3,3)
sns.boxplot(data=tecnologia_general['Total_tecnologia'])
plt.title('Total')

plt.show()

# %% [markdown]
# Pasa lo mismo que mencione anteriormente.

# %% [markdown]
# Seguimos con acceso_ingreso_bajada

# %%
accesos_ingresos_bajada = pd.read_csv('nuevos_datos/accesos_ingresos_y_media_de_bajada.csv')

# %%
accesos_ingresos_bajada
# Out:
#      Año  Trimestre Accesos por cada 100 hogares Accesos por cada 100 hab  \
# 0   2022          4                        77,21                    24,15
# 1   2022          3                        76,64                    23,95
# 2   2022          2                        75,97                    23,72
# 3   2022          1                        73,88                    23,05
# 4   2021          4                        73,18                    22,81
# 5   2021          3                        70,58                    21,98
# 6   2021          2                        69,24                    21,55
# 7   2021          1                        67,95                    21,13
# 8   2020          4                        67,62                    21,01
# 9   2020          3                        66,31                    20,59
# 10  2020          2                        64,21                    19,92
# 11  2020          1                        62,86                    19,48
# ...

# %% [markdown]
# A simple vista no se notaria ningun valor faltante.

# %% [markdown]
# seguiremos realizando boxplots en las columnas ingresos y mbps

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.boxplot(data=accesos_ingresos_bajada['Ingresos (miles de pesos)'])
plt.title('Ingresos')

plt.subplot(1,2,2)
sns.boxplot(data=accesos_ingresos_bajada['Mbps (Media de bajada)'])
plt.title('bajada promedio mbps')

plt.show()

# %% [markdown]
# vemos que el unico dato que se nota atipico serian los datos de el indice 0, esto no conlleva problemas en el analisis por lo tanto no lo eliminare.

# %% [markdown]
# Bien terminado el EDA en los archivos generales, seguiremos con los archivos de provincias.

# %% [markdown]
# comenzaremos con banda_ancha_provincias

# %%
banda_ancha_provincias = pd.read_csv('nuevos_datos/banda_ancha_provincias.csv')

# %% [markdown]
# Comenzaremos buscando valores nulos

# %%
banda_ancha_provincias[banda_ancha_provincias['Banda ancha fija'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, Banda ancha fija, Dial up, indice]
# Index: []

# %%
banda_ancha_provincias[banda_ancha_provincias['Dial up'].isna() == True]
# Out:
#       Año  Trimestre Provincia  Banda ancha fija  Dial up  indice
# 440  2018          2   Formosa                45      NaN     440
# 445  2018          2  Misiones               106      NaN     445

# %% [markdown]
# Aqui encontramos valores nulos, lo que hare sera rellenarlos con 0

# %%
banda_ancha_provincias['Dial up'].iloc[440] = 0
banda_ancha_provincias['Dial up'].iloc[445] = 0
# Out:
# C:\Users\Win10\AppData\Local\Temp\ipykernel_9020\3337664914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   banda_ancha_provincias['Dial up'].iloc[440] = 0
# C:\Users\Win10\AppData\Local\Temp\ipykernel_9020\3337664914.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   banda_ancha_provincias['Dial up'].iloc[445] = 0

# %% [markdown]
# una vez terminada la inspeccion de datos nulos lo que hare sera verificar si hay datos atipicos.

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.boxplot(data=banda_ancha_provincias['Banda ancha fija'])
plt.title('Banda ancha')

plt.subplot(1,2,2)
sns.boxplot(data=banda_ancha_provincias['Dial up'])
plt.title('Dial up')

plt.show()

# %% [markdown]
# Haremos un filtro para tratar de entener a que se deben estos valores atipicos.

# %%
banda_ancha_provincias[banda_ancha_provincias['Banda ancha fija'] > 800]
# Out:
#       Año  Trimestre Provincia  Banda ancha fija  Dial up  indice
# 20   2022          4  Santa Fe               888    110.0      20
# 44   2022          3  Santa Fe               888    110.0      44
# 68   2022          2  Santa Fe               879    110.0      68
# 92   2022          1  Santa Fe               870    115.0      92
# 101  2021          4   Córdoba               987     77.0     101
# 116  2021          4  Santa Fe               866    176.0     116
# 125  2021          3   Córdoba               947     62.0     125
# 140  2021          3  Santa Fe               841    151.0     140
# 149  2021          2   Córdoba               931     62.0     149
# 164  2021          2  Santa Fe               840    151.0     164
# 173  2021          1   Córdoba               911     55.0     173
# 188  2021          1  Santa Fe               826    137.0     188
# 197  2020          4   Córdoba               903     55.0     197
# ...

# %% [markdown]
# despues del filtro vemos que se da en 2 de las provincias grandes de la Argentina, lo cual es entendible el aumento de la banda acha fija.

# %%
banda_ancha_provincias[banda_ancha_provincias['Dial up'] > 800]
# Out:
#       Año  Trimestre  Provincia  Banda ancha fija  Dial up  indice
# 4    2022          4     Chubut               168    904.0       4
# 28   2022          3     Chubut               165    904.0      28
# 52   2022          2     Chubut               162    904.0      52
# 76   2022          1     Chubut               171    927.0      76
# 100  2021          4     Chubut               159    944.0     100
# 108  2021          4    Mendoza               267    804.0     108
# 148  2021          2     Chubut               138    825.0     148
# 172  2021          1     Chubut               132    825.0     172
# 196  2020          4     Chubut               130    825.0     196
# 220  2020          3     Chubut               129    825.0     220
# 244  2020          2     Chubut               108    825.0     244
# 292  2019          4     Chubut                95    810.0     292
# 327  2019          3  Río Negro               143    904.0     327
# ...

# %% [markdown]
# Con este filtro podemos ver que el aumento de los diales se debe a una baja en la parte de banda ancha fija, no eliminare datos porque no seran de estorbo al realizar el analisis.

# %% [markdown]
# ahora volvere a guardar este csv para que se guarden las correcciones en los valores faltantes.

# %%
banda_ancha_provincias.to_csv('nuevos_datos/banda_ancha_provincias.csv',index=False)

# %% [markdown]
# ahora seguire con el dataframe velocidad_provincias

# %%
velocidad_provincias = pd.read_csv('nuevos_datos/velocidad_provincias.csv')

# %% [markdown]
# comenzare buscando valores nulos

# %%
velocidad_provincias[velocidad_provincias['hasta 1 mbps'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, + 30 Mbps, OTROS, Total, hasta 1 mbps, 1 mbps - 10 mbps, 10 Mbps - 30 Mbps, indice]
# Index: []

# %%
velocidad_provincias[velocidad_provincias['1 mbps - 10 mbps'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, + 30 Mbps, OTROS, Total, hasta 1 mbps, 1 mbps - 10 mbps, 10 Mbps - 30 Mbps, indice]
# Index: []

# %%
velocidad_provincias[velocidad_provincias['10 Mbps - 30 Mbps'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, + 30 Mbps, OTROS, Total, hasta 1 mbps, 1 mbps - 10 mbps, 10 Mbps - 30 Mbps, indice]
# Index: []

# %%
velocidad_provincias[velocidad_provincias['+ 30 Mbps'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, + 30 Mbps, OTROS, Total, hasta 1 mbps, 1 mbps - 10 mbps, 10 Mbps - 30 Mbps, indice]
# Index: []

# %%
velocidad_provincias[velocidad_provincias['Total'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, + 30 Mbps, OTROS, Total, hasta 1 mbps, 1 mbps - 10 mbps, 10 Mbps - 30 Mbps, indice]
# Index: []

# %%
velocidad_provincias[velocidad_provincias['OTROS'].isna() == True]
# Out:
#       Año  Trimestre         Provincia  + 30 Mbps  OTROS    Total  \
# 337  2019          2   Capital Federal     475991    NaN  1418395
# 347  2019          2          La Rioja       1298    NaN    50304
# 348  2019          2           Mendoza        234    NaN   222260
# 355  2019          2        Santa Cruz          4    NaN    30010
# 358  2019          2  Tierra Del Fuego         32    NaN    47895
# 359  2019          2           Tucumán      18394    NaN   166673
#
#      hasta 1 mbps  1 mbps - 10 mbps  10 Mbps - 30 Mbps  indice
# 337          1767            405457             535846     337
# 347           200             44116               4987     347
# 348          2722            208136              11348     348
# 355          1090             28667               1482     355
# 358          1290             46065               2533     358
# 359          1730            123187              30571     359

# %% [markdown]
# Al haber encontrado nulos lo que hare sera guardar el indice para despues rellenar esos valores con 0

# %%
indices_nulos = velocidad_provincias[velocidad_provincias['OTROS'].isna() == True].index

# %% [markdown]
# crearé un for para ir rellenando los valores con 0

# %%
for i in indices_nulos:
    velocidad_provincias['OTROS'].iloc[i] = 0
# Out:
# C:\Users\Win10\AppData\Local\Temp\ipykernel_9020\1523764526.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   velocidad_provincias['OTROS'].iloc[i] = 0
# C:\Users\Win10\AppData\Local\Temp\ipykernel_9020\1523764526.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   velocidad_provincias['OTROS'].iloc[i] = 0
# C:\Users\Win10\AppData\Local\Temp\ipykernel_9020\1523764526.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# verificamos que tal quedaron los datos

# %%
velocidad_provincias[velocidad_provincias['OTROS'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, + 30 Mbps, OTROS, Total, hasta 1 mbps, 1 mbps - 10 mbps, 10 Mbps - 30 Mbps, indice]
# Index: []

# %% [markdown]
# Una vez finalizado la parte de los nulos, lo que hare será buscar valores atipicos.

# %%
velocidad_provincias.head(1)
# Out:
#     Año  Trimestre     Provincia  + 30 Mbps    OTROS    Total  hasta 1 mbps  \
# 0  2022          4  Buenos Aires    3760109  97634.0  4794665         52281
#
#    1 mbps - 10 mbps  10 Mbps - 30 Mbps  indice
# 0            288021             254422       0

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
sns.boxplot(data=velocidad_provincias['hasta 1 mbps'])
plt.title('hasta 1 mbps')

plt.subplot(1,3,2)
sns.boxplot(data=velocidad_provincias['1 mbps - 10 mbps'])
plt.title('1 mbps - 10 mbps')

plt.subplot(1,3,3)
sns.boxplot(data=velocidad_provincias['10 Mbps - 30 Mbps'])
plt.title('10 mbps - 30 mbps')

plt.show()

# %% [markdown]
# Luego de ver los graficos, hare un filtro para ver si se trata de un error humano.

# %%
velocidad_provincias[velocidad_provincias['hasta 1 mbps'] > 150000]
# Out:
#       Año  Trimestre     Provincia  + 30 Mbps    OTROS    Total  hasta 1 mbps  \
# 336  2019          2  Buenos Aires     985767  43438.0  3870807        246620
# 360  2019          1  Buenos Aires     705769   6369.0  3732709        234809
# 384  2018          4  Buenos Aires     265386  19125.0  3636606        208434
# 816  2014          2  Buenos Aires       4309      0.0  2659316        169176
# 840  2014          1  Buenos Aires       4037      0.0  2624542        179713
#
#      1 mbps - 10 mbps  10 Mbps - 30 Mbps  indice
# 336           1654044             940938     336
# 360           1632475            1153287     360
# 384           1616889            1526772     384
# 816           2428998              59389     816
# 840           2401662              40983     840

# %% [markdown]
# bien al filtrar los datos, vemos que en años anteriores al 2020 si era mas frecuente usar la velocidad de hasta 1 mbps.

# %% [markdown]
# seguire con los filtros

# %%
velocidad_provincias[velocidad_provincias['1 mbps - 10 mbps'] > 1500000]
# Out:
#       Año  Trimestre     Provincia  + 30 Mbps     OTROS    Total  \
# 312  2019          3  Buenos Aires    1246209   42294.0  3971683
# 336  2019          2  Buenos Aires     985767   43438.0  3870807
# 360  2019          1  Buenos Aires     705769    6369.0  3732709
# 384  2018          4  Buenos Aires     265386   19125.0  3636606
# 408  2018          3  Buenos Aires     237248  120464.0  3609754
# 432  2018          2  Buenos Aires     199589  113357.0  3502314
# 456  2018          1  Buenos Aires     184203  105818.0  3471700
# 480  2017          4  Buenos Aires     151747  114182.0  3188332
# 504  2017          3  Buenos Aires     108400       0.0  3028468
# 528  2017          2  Buenos Aires      46178       0.0  2976720
# 552  2017          1  Buenos Aires      22299       0.0  3186724
# 576  2016          4  Buenos Aires      17279       0.0  3138541
# 600  2016          3  Buenos Aires      13318       0.0  3121140
# ...

# %% [markdown]
# En este caso, veo el mismo comportamiento que en el anterior filtro.

# %%
velocidad_provincias[velocidad_provincias['10 Mbps - 30 Mbps'] > 1000000]
# Out:
#       Año  Trimestre     Provincia  + 30 Mbps     OTROS    Total  \
# 360  2019          1  Buenos Aires     705769    6369.0  3732709
# 384  2018          4  Buenos Aires     265386   19125.0  3636606
# 432  2018          2  Buenos Aires     199589  113357.0  3502314
# 456  2018          1  Buenos Aires     184203  105818.0  3471700
#
#      hasta 1 mbps  1 mbps - 10 mbps  10 Mbps - 30 Mbps  indice
# 360        234809           1632475            1153287     360
# 384        208434           1616889            1526772     384
# 432         82363           1754900            1352105     432
# 456         76280           1738484            1366915     456

# %% [markdown]
# Aqui vemos que no son valores realmente atipicos porque si vemos que en 2018 - 2019  y en la provincia mas grande de Argentina, notamos que para ese entonces comenzaba a ser mas usual el comenzar a tener mejor conectibidad a internet.

# %% [markdown]
# realizar otro grafico con las columnas que me faltan.

# %%
plt.figure(figsize=(14,4))

plt.subplot(1,3,1)
sns.boxplot(data=velocidad_provincias['+ 30 Mbps'])
plt.title('+ 30 mbps')

plt.subplot(1,3,2)
sns.boxplot(data=velocidad_provincias['OTROS'])
plt.title('OTROS')

plt.subplot(1,3,3)
sns.boxplot(data=velocidad_provincias['Total'])
plt.title('Total')

plt.show()

# %% [markdown]
# hare unos filtros para verificar los valores atipicos que se muestran en los graficos.

# %%
velocidad_provincias[velocidad_provincias['+ 30 Mbps'] > 2500000]
# Out:
#      Año  Trimestre     Provincia  + 30 Mbps    OTROS    Total  hasta 1 mbps  \
# 0   2022          4  Buenos Aires    3760109  97634.0  4794665         52281
# 24  2022          3  Buenos Aires    3618689  65821.0  4721668         57694
# 48  2022          2  Buenos Aires    3535757  65849.0  4667183         58962
# 72  2022          1  Buenos Aires    3381049   2628.0  4555424         61647
# 96  2021          4  Buenos Aires    3259793  22958.0  4509157         48847
#
#     1 mbps - 10 mbps  10 Mbps - 30 Mbps  indice
# 0             288021             254422       0
# 24            588230             279463      24
# 48            602792             403823      48
# 72            635138             451310      72
# 96            684242             493317      96

# %% [markdown]
# Aqui esta lo que venia explicando en los anteriores filtros, porque en los años posteriores al 2020, la necesidad de una mejor conecctibidad a internet fue en aumento, esto debido al cambio de vida de todos los Argentinos por la pandemia en 2020

# %% [markdown]
# seguire con los filtros

# %%
velocidad_provincias[velocidad_provincias['OTROS'] > 80000]
# Out:
#       Año  Trimestre        Provincia  + 30 Mbps     OTROS    Total  \
# 0    2022          4     Buenos Aires    3760109   97634.0  4794665
# 1    2022          4  Capital Federal    1299117  106772.0  1551926
# 25   2022          3  Capital Federal    1253105  105477.0  1547679
# 49   2022          2  Capital Federal    1229254  105607.0  1536771
# 408  2018          3     Buenos Aires     237248  120464.0  3609754
# 432  2018          2     Buenos Aires     199589  113357.0  3502314
# 456  2018          1     Buenos Aires     184203  105818.0  3471700
# 480  2017          4     Buenos Aires     151747  114182.0  3188332
#
#      hasta 1 mbps  1 mbps - 10 mbps  10 Mbps - 30 Mbps  indice
# 0           52281            288021             254422       0
# 1           10256             95973              44452       1
# 25          10912            102200              80638      25
# 49           5768            108470              86943      49
# ...

# %% [markdown]
# Este aumento podria ser debido a planes de consumo alternativos ya que vemos que el servicio de 1 mbps se estaba comenzando a dejar de usar y algunas personas comenzarian a optar por otros servicios.

# %%
velocidad_provincias[velocidad_provincias['Total'] > 4000000]
# Out:
#       Año  Trimestre     Provincia  + 30 Mbps    OTROS    Total  hasta 1 mbps  \
# 0    2022          4  Buenos Aires    3760109  97634.0  4794665         52281
# 24   2022          3  Buenos Aires    3618689  65821.0  4721668         57694
# 48   2022          2  Buenos Aires    3535757  65849.0  4667183         58962
# 72   2022          1  Buenos Aires    3381049   2628.0  4555424         61647
# 96   2021          4  Buenos Aires    3259793  22958.0  4509157         48847
# 120  2021          3  Buenos Aires    2482266   9728.0  4251609         68342
# 144  2021          2  Buenos Aires    2337604   9108.0  4132351         68370
# 168  2021          1  Buenos Aires    2246313  10867.0  4060002         68126
# 192  2020          4  Buenos Aires    2176242   9016.0  4033261         68136
#
#      1 mbps - 10 mbps  10 Mbps - 30 Mbps  indice
# 0              288021             254422       0
# 24             588230             279463      24
# ...

# %% [markdown]
# En cuanto a esta columna de Total, se debe al aumento de consumo de internet debido a lo mencionado anteriormente.

# %% [markdown]
# para finalizar guardare de nuevo los datos para que queden guardados los valores en donde eran valores nulos.

# %%
velocidad_provincias.to_csv('nuevos_datos/velocidad_provincias.csv',index=False)

# %%
tecnologia_provincias = pd.read_csv('nuevos_datos/tecnologia_provincias.csv')

# %% [markdown]
# comenzare buscando nulos

# %%
tecnologia_provincias[tecnologia_provincias['ADSL'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, ADSL, Cablemodem, Fibra óptica, Wireless, Otros, indice]
# Index: []

# %%
tecnologia_provincias[tecnologia_provincias['Cablemodem'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, ADSL, Cablemodem, Fibra óptica, Wireless, Otros, indice]
# Index: []

# %%
tecnologia_provincias[tecnologia_provincias['Fibra óptica'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, ADSL, Cablemodem, Fibra óptica, Wireless, Otros, indice]
# Index: []

# %%
tecnologia_provincias[tecnologia_provincias['Wireless'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, ADSL, Cablemodem, Fibra óptica, Wireless, Otros, indice]
# Index: []

# %%
tecnologia_provincias[tecnologia_provincias['Otros'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, ADSL, Cablemodem, Fibra óptica, Wireless, Otros, indice]
# Index: []

# %% [markdown]
# como vemos no contiene nulos, ahora hare un analisis en busca de valores atipicos.

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
sns.boxplot(data=tecnologia_provincias['ADSL'])
plt.title('ADSL')

plt.subplot(1,3,2)
sns.boxplot(data=tecnologia_provincias['Cablemodem'])
plt.title('Cable Modem')

plt.subplot(1,3,3)
sns.boxplot(data=tecnologia_provincias['Fibra óptica'])
plt.title('Fibra optica')

plt.show()

# %% [markdown]
# Luego de realizar estos graficos, lo que hare sera hacer una serie de filtros para verificar estos valores atipicos.

# %%
tecnologia_provincias[tecnologia_provincias['ADSL'] > 500]
# Out:
#       Año Trimestre        Provincia   ADSL  Cablemodem  Fibra óptica  \
# 120  2021         3     Buenos Aires  586.0         3.0         886.0
# 144  2021         2     Buenos Aires  603.0         3.0         854.0
# 168  2021         1     Buenos Aires  630.0         2.0         822.0
# 192  2020         4     Buenos Aires  636.0         2.0         805.0
# 216  2020         3     Buenos Aires  654.0         2.0         749.0
# 240  2020         2     Buenos Aires  661.0         2.0         723.0
# 264  2020         1     Buenos Aires  673.0         2.0         721.0
# 288  2019         4     Buenos Aires  720.0         2.0         669.0
# 481  2017         4  Capital Federal  571.0       962.0          36.0
# 505  2017         3  Capital Federal  583.0       941.0          33.0
# 529  2017         2  Capital Federal  615.0       932.0          39.0
#
#      Wireless  Otros  indice
# 120     120.0   65.0     120
# 144     114.0   58.0     144
# 168      99.0   58.0     168
# ...

# %% [markdown]
# Bien aqui vemos un aumento en la cantidad del servicio ADSL pero puede ser entendible ya que es en dos de las grandes provincias de la Argentina.

# %%
tecnologia_provincias[tecnologia_provincias['Cablemodem'] > 800]
# Out:
#       Año Trimestre        Provincia   ADSL  Cablemodem  Fibra óptica  \
# 433  2018         2  Capital Federal  342.0       978.0          36.0
# 457  2018         1  Capital Federal  350.0       968.0          36.0
# 481  2017         4  Capital Federal  571.0       962.0          36.0
# 505  2017         3  Capital Federal  583.0       941.0          33.0
# 529  2017         2  Capital Federal  615.0       932.0          39.0
# 553  2017         1  Capital Federal  429.0       918.0          38.0
# 556  2017         1           Chubut   44.0       999.0         916.0
# 577  2016         4  Capital Federal  435.0       915.0          38.0
# 580  2016         4           Chubut   44.0       955.0         916.0
# 601  2016         3  Capital Federal  448.0       905.0          37.0
# 604  2016         3           Chubut   44.0       935.0         916.0
# 625  2016         2  Capital Federal  451.0       892.0          37.0
# ...

# %% [markdown]
# vemos que el servicio de cable tuvo un gran aumento entre los años de 2014 a 2018, lo cual podria explicar porque tuvo ese aumento es que este servicio antes era mas usado que en estos años, luego tomo mas relevancia el servicio de fibra optica al ser un servicio mejor.

# %%
tecnologia_provincias[tecnologia_provincias['Fibra óptica'] > 800]
# Out:
#         Año Trimestre            Provincia   ADSL  Cablemodem  Fibra óptica  \
# 120    2021         3         Buenos Aires  586.0         3.0         886.0
# 141    2021         3  Santiago Del Estero   20.0        86.0         909.0
# 144    2021         2         Buenos Aires  603.0         3.0         854.0
# 165    2021         2  Santiago Del Estero   21.0        84.0         909.0
# 168    2021         1         Buenos Aires  630.0         2.0         822.0
# 192    2020         4         Buenos Aires  636.0         2.0         805.0
# 297    2019         4                Jujuy   33.0        38.0         873.0
# 301    2019         4             Misiones   53.0        70.0         847.0
# 325  2019 *       3 *             Misiones   54.0        66.0         829.0
# 331  2019 *       3 *           Santa Cruz   11.0        17.0         969.0
# 368  2019 *       1 *              Formosa   23.0         8.0         940.0
# ...

# %% [markdown]
# La fibra optica tuvo un numeros bastante grandes desde el principio en varias provincias de la Argentina.

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.boxplot(data=tecnologia_provincias['Wireless'])
plt.title('Wireless')

plt.subplot(1,2,2)
sns.boxplot(data=tecnologia_provincias['Otros'])
plt.title('Otros')

plt.show()

# %% [markdown]
# Volvere a realizar filtro para verificar los valores atipicos.

# %%
tecnologia_provincias[tecnologia_provincias['Wireless'] > 800]
# Out:
#         Año Trimestre            Provincia  ADSL  Cablemodem  Fibra óptica  \
# 225    2020         3                Jujuy  33.0        58.0          11.0
# 249    2020         2                Jujuy  33.0        39.0           5.0
# 273    2020         1                Jujuy  32.0        39.0           3.0
# 297    2019         4                Jujuy  33.0        38.0         873.0
# 321  2019 *       3 *                Jujuy  33.0        36.0         274.0
# 345  2019 *       2 *                Jujuy  33.0        31.0         274.0
# 525    2017         3  Santiago Del Estero  28.0        54.0          19.0
# 549    2017         2  Santiago Del Estero  28.0         4.0          19.0
# 573    2017         1  Santiago Del Estero  30.0         4.0          19.0
# 597    2016         4  Santiago Del Estero  30.0         4.0          19.0
# 645    2016         2  Santiago Del Estero  32.0         4.0          19.0
# ...

# %% [markdown]
# vemos que desde el principio del 2014 hasta finales del 2020 tuvo un gran aumento, no considero que influyan para mal en el analisis.

# %%
tecnologia_provincias[tecnologia_provincias['Otros'] > 800]
# Out:
#       Año Trimestre Provincia  ADSL  Cablemodem  Fibra óptica  Wireless  \
# 132  2021         3   Mendoza  91.0        71.0          71.0      22.0
# 156  2021         2   Mendoza  92.0        71.0          45.0      22.0
# 180  2021         1   Mendoza  92.0        69.0          39.0      18.0
# 204  2020         4   Mendoza  92.0        68.0          36.0      18.0
# 228  2020         3   Mendoza  92.0        65.0          33.0      18.0
# 252  2020         2   Mendoza  92.0        63.0          30.0      16.0
# 302  2019         4   Neuquén  30.0        61.0          11.0      14.0
# 418  2018         3  La Pampa  12.0        55.0           8.0       7.0
# 442  2018         2  La Pampa  12.0        54.0           8.0       7.0
# 544  2017         2     Salta  80.0        27.0         115.0     158.0
# 545  2017         2  San Juan  49.0       451.0         772.0       1.0
# 569  2017         1  San Juan  49.0       451.0         772.0       1.0
# ...

# %% [markdown]
# vemos que otros servicios tuvieron un aumento cuando los otros servicios bajaron.

# %% [markdown]
# Seguiremos con Bajada_provincias

# %%
bajada_provincias = pd.read_csv('nuevos_datos/bajada_provincias.csv')

# %%
bajada_provincias
# Out:
#       Año  Trimestre            Provincia  Mbps (miles)
# 0    2022          4         Buenos Aires           111
# 1    2022          4      Capital Federal            18
# 2    2022          4            Catamarca             8
# 3    2022          4                Chaco            10
# 4    2022          4               Chubut             1
# ..    ...        ...                  ...           ...
# 859  2014          1           Santa Cruz           332
# 860  2014          1             Santa Fe           315
# 861  2014          1  Santiago Del Estero           295
# 862  2014          1     Tierra Del Fuego           345
# 863  2014          1              Tucumán           321
#
# [864 rows x 4 columns]

# %% [markdown]
# comenzare con la busqueda de valores nulos

# %%
bajada_provincias[bajada_provincias['Mbps (miles)'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, Mbps (miles)]
# Index: []

# %% [markdown]
# no contiene datos nulos, seguiremos con la busqueda de valores atipicos.

# %%
sns.boxplot(data=bajada_provincias['Mbps (miles)'])
# Out:
# <Axes: >

# %% [markdown]
# como vemos en la grafica, no contiene valores atipicos.

# %% [markdown]
# Aqui termina mi EDA.

# %%
print('Gracias por ver')
# Out:
# Gracias por ver
